# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/23 15:57:17 WARN Utils: Your hostname, spark-e169, resolves to a loopback address: 127.0.0.1; using 192.168.1.104 instead (on interface enP7s7)
# 26/07/23 15:57:17 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/23 15:57:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/07/23 15:57:17 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/07/23 15:57:17 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
data_path = './24-advanced-sql/02-sql-and-big-data/linkedin-learning-apache-spark-and-data-analysis/Exercise-Files/Data'

# %%
json_df1_path = data_path + '/utilization.json'

# %%
df1 = spark.read.format('json').load(json_df1_path)

# %%
df1.count()
# Out:
# 500000

# %%
df1.show()
# Out:
# +---------------+-------------------+-----------+---------+-------------+
# |cpu_utilization|     event_datetime|free_memory|server_id|session_count|
# +---------------+-------------------+-----------+---------+-------------+
# |           0.57|03/05/2019 08:06:14|       0.51|      100|           47|
# |           0.47|03/05/2019 08:11:14|       0.62|      100|           43|
# |           0.56|03/05/2019 08:16:14|       0.57|      100|           62|
# |           0.57|03/05/2019 08:21:14|       0.56|      100|           50|
# |           0.35|03/05/2019 08:26:14|       0.46|      100|           43|
# |           0.41|03/05/2019 08:31:14|       0.58|      100|           48|
# |           0.57|03/05/2019 08:36:14|       0.35|      100|           58|
# |           0.41|03/05/2019 08:41:14|        0.4|      100|           58|
# |           0.53|03/05/2019 08:46:14|       0.35|      100|           62|
# |           0.51|03/05/2019 08:51:14|        0.6|      100|           45|
# |           0.32|03/05/2019 08:56:14|       0.37|      100|           47|
# |           0.62|03/05/2019 09:01:14|       0.59|      100|           60|
# |           0.66|03/05/2019 09:06:14|       0.72|      100|           57|
# |           0.54|03/05/2019 09:11:14|       0.54|      100|           44|
# |           0.29|03/05/2019 09:16:14|        0.4|      100|           47|
# |           0.43|03/05/2019 09:21:14|       0.68|      100|           66|
# |           0.49|03/05/2019 09:26:14|       0.66|      100|           65|
# |           0.64|03/05/2019 09:31:14|       0.55|      100|           66|
# |           0.42|03/05/2019 09:36:14|        0.6|      100|           42|
# |           0.55|03/05/2019 09:41:14|       0.59|      100|           63|
# +---------------+-------------------+-----------+---------+-------------+
# only showing top 20 rows

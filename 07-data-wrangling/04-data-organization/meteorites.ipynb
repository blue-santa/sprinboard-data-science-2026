# %% [markdown]
# ## YData Profiling: NASA Meteorites example
# Source of data: https://data.nasa.gov/docs/legacy/meteorite_landings/Meteorite_Landings.csv

# %% [markdown]
# The autoreload instruction reloads modules automatically before code execution, which is helpful for the update below.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Make sure that we have the latest version of pandas-profiling.

# %%
import sys

# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Collecting ydata-profiling[notebook]
#   Using cached ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (2.3.2)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling[notebook])
#   Using cached matplotlib-3.10.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic<3,>=2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook])
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (2.1.0)
# Collecting minify-html>=0.15.0 (from ydata-profiling[notebook])
#   Using cached minify_html-0.18.1-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling[notebook])
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling[notebook])
#   Using cached phik-0.12.5.tar.gz (621 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3,>=2.32.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling[notebook])
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling[notebook])
#   Using cached statsmodels-0.14.6-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=4 (from ydata-profiling[notebook])
#   Using cached typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling[notebook])
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling[notebook])
#   Using cached wordcloud-1.9.6-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (3.4 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling[notebook])
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<0.63,>=0.60 (from ydata-profiling[notebook])
#   Using cached numba-0.62.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (2.8 kB)
# Collecting jupyter>=1.0.0 (from ydata-profiling[notebook])
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipywidgets>=7.5.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ydata-profiling[notebook]) (8.1.7)
# Collecting PyWavelets (from imagehash==4.3.2->ydata-profiling[notebook])
#   Using cached pywavelets-1.9.0-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (7.6 kB)
# Requirement already satisfied: pillow in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling[notebook]) (11.3.0)
# Requirement already satisfied: comm>=0.1.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling[notebook]) (3.0.3)
# Requirement already satisfied: notebook in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.5.4)
# Collecting jupyter-console (from jupyter>=1.0.0->ydata-profiling[notebook])
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.6)
# Requirement already satisfied: ipykernel in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.31.0)
# Requirement already satisfied: jupyterlab in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (4.5.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba<0.63,>=0.60->ydata-profiling[notebook])
#   Using cached llvmlite-0.45.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling[notebook]) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from phik<0.13,>=0.12.5->ydata-profiling[notebook]) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling[notebook]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling[notebook]) (2025.11.12)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling[notebook])
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.6.1)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook])
#   Using cached puremagic-2.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: decorator>=4.3.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.6.3)
# Requirement already satisfied: six>=1.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.17.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.19)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.4)
# Requirement already satisfied: async-lru>=1.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (80.9.0)
# Requirement already satisfied: beautifulsoup4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (6.3.0)
# Requirement already satisfied: defusedxml in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.3)
# Requirement already satisfied: nbformat>=5.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: webencodings in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.4.0)
# Requirement already satisfied: anyio in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (4.5.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.25.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: wcwidth in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.1)
# Requirement already satisfied: pure-eval in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.8.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Requirement already satisfied: fqdn in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: isoduration in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.1.0)
# Requirement already satisfied: uri-template in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.0)
# Requirement already satisfied: pycparser in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.4.0)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached dacite-1.9.2-py3-none-any.whl (16 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (8.4 MB)
# Using cached minify_html-0.18.1-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (2.9 MB)
# Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# Using cached numba-0.62.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (3.5 MB)
# Using cached statsmodels-0.14.6-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (10.1 MB)
# Using cached typeguard-4.5.1-py3-none-any.whl (36 kB)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached wordcloud-1.9.6-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (547 kB)
# Using cached ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Using cached llvmlite-0.45.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (55.1 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached puremagic-2.0.0-py3-none-any.whl (65 kB)
# Using cached pywavelets-1.9.0-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (4.4 MB)
# Building wheels for collected packages: phik
#   Building wheel for phik (pyproject.toml) ... done
#   Created wheel for phik: filename=phik-0.12.5-cp312-cp312-linux_aarch64.whl size=683770 sha256=d0e52436b113448e3da07d0151b185f093f4ed2f936c8ceaefca78ce04bf13d9
#   Stored in directory: /home/bluesanta/.cache/pip/wheels/4b/d2/03/fd5045d098c6b8a3bf9306a6b9221c966256b17105e3cfd3fb
# Successfully built phik
# Installing collected packages: minify-html, filetype, typeguard, PyWavelets, puremagic, patsy, multimethod, llvmlite, dacite, numba, matplotlib, imagehash, wordcloud, visions, statsmodels, phik, jupyter-console, ydata-profiling, jupyter
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.6
#     Uninstalling matplotlib-3.10.6:
#       Successfully uninstalled matplotlib-3.10.6
# Successfully installed PyWavelets-1.9.0 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 jupyter-1.1.1 jupyter-console-6.6.3 llvmlite-0.45.1 matplotlib-3.10.0 minify-html-0.18.1 multimethod-1.12 numba-0.62.1 patsy-1.0.2 phik-0.12.5 puremagic-2.0.0 statsmodels-0.14.6 typeguard-4.5.1 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1
# Requirement already satisfied: jupyter-contrib-nbextensions in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.9.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (7.5.4)
# Requirement already satisfied: tornado in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (6.5.4)
# Requirement already satisfied: traitlets>=4.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (5.14.3)
# Requirement already satisfied: lxml in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-contrib-nbextensions) (6.0.2)
# Requirement already satisfied: setuptools in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions) (80.9.0)
# Requirement already satisfied: jupyter-server in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.17.0)
# Requirement already satisfied: pyyaml in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (6.3.0)
# Requirement already satisfied: defusedxml in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.10.3)
# Requirement already satisfied: nbformat>=5.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.10.4)
# Requirement already satisfied: packaging in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.19.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter_core->jupyter-contrib-nbextensions) (4.5.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.5.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.4)
# Requirement already satisfied: webencodings in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.4.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (4.12.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (8.7.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (6.31.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (2.3.0)
# Requirement already satisfied: babel>=2.10 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.32.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.21.2)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.0)
# Requirement already satisfied: certifi in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (9.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (7.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.6.2)
# Requirement already satisfied: ptyprocess in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (0.7.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.6.3)
# Requirement already satisfied: fqdn in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (25.10.0)
# Requirement already satisfied: six>=1.5 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2.23)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.5)
# Requirement already satisfied: wcwidth in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.14)
# Requirement already satisfied: lark>=1.2.2 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.1)
# Requirement already satisfied: pure-eval in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.5->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (1.4.0)
# Requirement already satisfied: tzdata in /home/bluesanta/jupyterlab/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions) (2025.3)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %% [markdown]
# You might want to restart the kernel now.

# %% [markdown]
# ### Import libraries

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import requests

import ydata_profiling
from ydata_profiling.utils.cache import cache_file

# %% [markdown]
# ### Load and prepare example dataset
# We add some fake variables for illustrating pandas-profiling capabilities

# %%
file_name = cache_file(
    "meteorites.csv",
    "https://data.nasa.gov/docs/legacy/meteorite_landings/Meteorite_Landings.csv",
)

df = pd.read_csv(file_name)

# Note: Pandas does not support dates before 1880, so we ignore these for this analysis
df["year"] = pd.to_datetime(df["year"], errors="coerce")

# Example: Constant variable
df["source"] = "NASA"

# Example: Boolean variable
df["boolean"] = np.random.choice([True, False], df.shape[0])

# Example: Mixed with base types
df["mixed"] = np.random.choice([1, "A"], df.shape[0])

# Example: Highly correlated variables
df["reclat_city"] = df["reclat"] + np.random.normal(scale=5, size=(len(df)))

# Example: Duplicate observations
duplicates_to_add = pd.DataFrame(df.iloc[0:10])
duplicates_to_add["name"] = duplicates_to_add["name"] + " copy"

df = pd.concat([df, duplicates_to_add], ignore_index=True)

# %% [markdown]
# ### Inline report without saving object

# %%
report = df.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report

# %% [markdown]
# ### Save report to file

# %%
profile_report = df.profile_report(html={"style": {"full_width": True}})
profile_report.to_file("/tmp/example.html")

# %% [markdown]
# ### More analysis (Unicode) and Print existing ProfileReport object inline

# %%
profile_report = df.profile_report(
    explorative=True, html={"style": {"full_width": True}}
)
profile_report

# %% [markdown]
# ### Notebook Widgets

# %%
profile_report.to_widgets()

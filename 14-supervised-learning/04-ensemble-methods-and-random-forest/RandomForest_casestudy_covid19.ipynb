# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble of Decision Trees. With a few exceptions, a `RandomForestClassifier` has all the hyperparameters of a `DecisionTreeClassifier` (to control how trees are grown), plus all the hyperparameters of a `BaggingClassifier` to control the ensemble itself.
#
# The Random Forest algorithm introduces extra randomness when growing trees; instead of searching for the very best feature when splitting a node, it searches for the best feature among a random subset of features. This results in a greater tree diversity, which (once again) trades a higher bias for a lower variance, generally yielding an overall better model. The following `BaggingClassifier` is roughly equivalent to the previous `RandomForestClassifier`. Run the cell below to visualize a single estimator from a random forest model, using the Iris dataset to classify the data into the appropriate species.

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# Model (can also use single decision tree)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# Train
model.fit(iris.data, iris.target)
# Extract single tree
estimator = model.estimators_[5]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = iris.feature_names,
                class_names = iris.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# Notice how each split seperates the data into buckets of similar observations. This is a single tree and a relatively simple classification dataset, but the same method is used in a more complex dataset with greater depth to the trees.

# %% [markdown]
# ## Coronavirus
# Coronavirus disease (COVID-19) is an infectious disease caused by a new virus.
# The disease causes respiratory illness (like the flu) with symptoms such as a cough, fever, and in more severe cases, difficulty breathing. You can protect yourself by washing your hands frequently, avoiding touching your face, and avoiding close contact (1 meter or 3 feet) with people who are unwell. An outbreak of COVID-19 started in December 2019 and at the time of the creation of this project was continuing to spread throughout the world. Many governments recommended only essential outings to public places and closed most business that do not serve food or sell essential items. An excellent [spatial dashboard](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) built by Johns Hopkins shows the daily confirmed cases by country.
#
# This case study was designed to drive home the important role that data science plays in real-world situations like this pandemic. This case study uses the Random Forest Classifier and a dataset from the South Korean cases of COVID-19 provided on [Kaggle](https://www.kaggle.com/kimjihoo/coronavirusdataset) to encourage research on this important topic. The goal of the case study is to build a Random Forest Classifier to predict the 'state' of the patient.

# %% [markdown]
# First, please load the needed packages and modules into Python. Next, load the data into a pandas dataframe for ease of use.

# %%
import os
import pandas as pd
from datetime import datetime, timedelta, date
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import plotly.graph_objects as go
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# %%
url ='SouthKoreacoronavirusdataset/PatientInfo.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
df.shape
# Out:
# (2218, 18)

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10                 age        261
# 11                 sex        145
# 12      confirmed_date        141
# 13               state         88
# 14                city         65

# %%
#counts of response variable values
df.state.value_counts()
# Out:
# state
# isolated    1791
# released     307
# deceased      32
# Name: count, dtype: int64

# %% [markdown]
#  **<font color='teal'> Create a new column named 'n_age' which is the calculated age based on the birth year column.</font>**

# %%
df['birth_year_dt'] = pd.to_datetime(df['birth_year'], format='%Y')

# %%
df['n_age'] = datetime.now().year - df['birth_year_dt'].dt.year

# %%
df['n_age'].head()
# Out:
# 0    62.0
# 1    39.0
# 2    62.0
# 3    35.0
# 4    34.0
# Name: n_age, dtype: float64

# %%
df['n_age'].describe()
# Out:
# count    1764.000000
# mean       51.011338
# std        19.412643
# min         6.000000
# 25%        33.000000
# 50%        51.500000
# 75%        64.000000
# max       110.000000
# Name: n_age, dtype: float64

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
#  **<font color='teal'> Print the number of missing values by column.</font>**

# %%
df.isna().sum()
# Out:
# patient_id               0
# global_num             904
# sex                    145
# birth_year             454
# age                    261
# country                  0
# province                 0
# city                    65
# disease               2199
# infection_case        1055
# infection_order       2176
# infected_by           1749
# contact_number        1807
# symptom_onset_date    2025
# confirmed_date         141
# released_date         1995
# deceased_date         2186
# state                   88
# birth_year_dt          454
# n_age                  454
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          1314 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          1764 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             19 non-null     object
#  9   infection_case      1163 non-null   object
#  10  infection_order     42 non-null     float64
#  11  infected_by         469 non-null    float64
#  12  contact_number      411 non-null    float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
# ...

# %% [markdown]
#  **<font color='teal'> Fill the 'disease' missing values with 0 and remap the True values to 1.</font>**

# %%
df['disease'] = df['disease'].fillna(0)

# %%
df.loc[df['disease'] == True, 'disease'] = 1

# %%
df['disease'].value_counts()
# Out:
# disease
# 0    2199
# 1      19
# Name: count, dtype: int64

# %% [markdown]
#  **<font color='teal'> Fill null values in the following columns with their mean: 'global_number','birth_year','infection_order','infected_by'and 'contact_number'</font>**

# %%
df['global_num'] = df['global_num'].fillna(df['global_num'].mean())
df['birth_year'] = df['birth_year'].fillna(df['birth_year'].mean().astype(int))
df['infection_order'] = df['infection_order'].fillna(df['infection_order'].mean())
df['infected_by'] = df['infected_by'].fillna(df['infected_by'].mean())
df['contact_number'] = df['contact_number'].fillna(df['contact_number'].mean())

# %% [markdown]
#  **<font color='teal'> Fill the rest of the missing values with any method.</font>**

# %% [markdown]
# #### sex

# %%
df.isna().sum()
# Out:
# patient_id               0
# global_num               0
# sex                    145
# birth_year               0
# age                    261
# country                  0
# province                 0
# city                    65
# disease                  0
# infection_case        1055
# infection_order          0
# infected_by              0
# contact_number           0
# symptom_onset_date    2025
# confirmed_date         141
# released_date         1995
# deceased_date         2186
# state                   88
# birth_year_dt          454
# n_age                  454
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# female    1171
# male       902
# Name: count, dtype: int64

# %%
prob_f = (df['sex'].value_counts().iloc[0]/df['sex'].notnull().sum())

# %%
temp_mask = df['sex'].isna()
choices = ['female', 'male']
probs = [prob_f, 1 - prob_f]

# %%
# Based on response from Google search query
df.loc[temp_mask, 'sex'] = np.random.choice(choices, size=temp_mask.sum(), p=probs)

# %%
df['sex'].value_counts()
# Out:
# sex
# female    1264
# male       954
# Name: count, dtype: int64

# %% [markdown]
# #### age

# %% [markdown]
# This column is redundant, given `n_age`. It can be dropped.

# %%
df['age'].apply(type).unique()
# Out:
# array([<class 'str'>, <class 'float'>], dtype=object)

# %%
df['age'][df['age'].apply(type) == str].value_counts()
# Out:
# age
# 20s     467
# 50s     385
# 40s     303
# 30s     251
# 60s     229
# 70s     117
# 80s      84
# 10s      74
# 0s       29
# 90s      17
# 100s      1
# Name: count, dtype: int64

# %%
temp_mask = df['age'][df['age'].apply(type) == str].index

# %%
df.loc[temp_mask, 'age'] = df.loc[temp_mask, 'age'].str[:-1]

# %%
df['age'] = df['age'].astype(float) + 5

# %%
df['age'][df['age'].apply(type) == float].value_counts()
# Out:
# age
# 25.0     467
# 55.0     385
# 45.0     303
# 35.0     251
# 65.0     229
# 75.0     117
# 85.0      84
# 15.0      74
# 5.0       29
# 95.0      17
# 105.0      1
# Name: count, dtype: int64

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['age'].value_counts()
# Out:
# age
# 25.000000     467
# 55.000000     385
# 45.000000     303
# 45.500766     261
# 35.000000     251
# 65.000000     229
# 75.000000     117
# 85.000000      84
# 15.000000      74
# 5.000000       29
# 95.000000      17
# 105.000000      1
# Name: count, dtype: int64

# %% [markdown]
# #### city
#
# To keep this simple, let's fill the `NaN` values with the local province. Getting the capital is too big of a project for this assignment, but could be accomplished with open datasets.

# %%
df['city'].isna().sum()
# Out:
# np.int64(65)

# %%
df['city'] = df['city'].fillna(df['province'])

# %%
df['city'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### infection_case

# %% [markdown]
# Check the options available.

# %%
df['infection_case'].value_counts()
# Out:
# infection_case
# contact with patient                530
# etc                                 220
# Guro-gu Call Center                 102
# Shincheonji Church                   86
# overseas inflow                      61
# Onchun Church                        33
# gym facility in Cheonan              30
# Ministry of Oceans and Fisheries     27
# Cheongdo Daenam Hospital             21
# Dongan Church                        17
# Eunpyeong St. Mary's Hospital        14
# Seongdong-gu APT                     13
# gym facility in Sejong                4
# Suyeong-gu Kindergarten               3
# River of Grace Community Church       1
# Pilgrimage to Israel                  1
# Name: count, dtype: int64

# %% [markdown]
# There's an `etc` value that looks like a general option. All `NaN` values should be that.

# %%
temp_mask = df['infection_case'][df['infection_case'].isna() == True]

# %%
df['infection_case'] = df['infection_case'].fillna('etc')

# %%
df['infection_case'].value_counts()
# Out:
# infection_case
# etc                                 1275
# contact with patient                 530
# Guro-gu Call Center                  102
# Shincheonji Church                    86
# overseas inflow                       61
# Onchun Church                         33
# gym facility in Cheonan               30
# Ministry of Oceans and Fisheries      27
# Cheongdo Daenam Hospital              21
# Dongan Church                         17
# Eunpyeong St. Mary's Hospital         14
# Seongdong-gu APT                      13
# gym facility in Sejong                 4
# Suyeong-gu Kindergarten                3
# River of Grace Community Church        1
# Pilgrimage to Israel                   1
# Name: count, dtype: int64

# %% [markdown]
# #### confirmed_date

# %% [markdown]
# Between the columns `confirmed_date` and `symptom_onset_date`, we have significantly more information about the former col than the later.
#
# Since the `symptom_onset_date` is lacking in information, and since the `confirmed_date` is likely to be more accurate by nature (since this would be the date a doctor confirmed the result with a test), let's work on this former col first.
#
# For any `confirmed_date` cols where we don't have data, let's first see if we have information in the `symptom_onset_date` col that could provide information.

# %%
df[(df['confirmed_date'].isna() == True) & (df['symptom_onset_date'].isna() == False)]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state, birth_year_dt, n_age]
# Index: []

# %% [markdown]
# There is no information. Therefore, let's just set the value of `confirmed_date` to the mean.

# %%
temp_mask_idx = df[df['confirmed_date'].isna() == False].index

# %%
df.loc[temp_mask_idx, 'confirmed_date'] = pd.to_datetime(df.loc[temp_mask_idx, 'confirmed_date'], format='%Y-%m-%d')

# %%
temp_mask = df['confirmed_date'].isna() == False

# %%
df['temp_date'] = pd.to_datetime(df['confirmed_date']).astype('int64')

# %%
temp_mean = datetime.fromtimestamp(df.loc[temp_mask, 'temp_date'].mean() // 10**9)

# %%
temp_mask = df['confirmed_date'].isna() == True

# %%
df.loc[temp_mask, 'confirmed_date'] = temp_mean

# %%
df = df.drop(columns=['temp_date'], axis=1)

# %% [markdown]
# #### symptom_onset_date

# %% [markdown]
# For this column, we'll just set the symptom_onset_date to the value of `confirmed_date`.

# %%
temp_mask = df['symptom_onset_date'].isna() == True

# %%
df.loc[temp_mask, 'symptom_onset_date'] = df.loc[temp_mask, 'confirmed_date']

# %% [markdown]
# #### Either `deceased_date` or `released_date`

# %% [markdown]
# Let's check to see if there are any instances where `state` is `NaN` but there is information in `released_date` or `deceased_date`.

# %%
df[['state', 'deceased_date', 'released_date']][(df['state'].isna() == True)].sum()
# Out:
# state            0
# deceased_date    0
# released_date    0
# dtype: object

# %% [markdown]
# There are no instances.

# %% [markdown]
# Let's check the overlap between `released_date` and `deceased_date`. Are there values where there are dates in both columns?

# %%
df[(df['released_date'].isna() == False) & (df['deceased_date'].isna() == False)]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state, birth_year_dt, n_age]
# Index: []

# %% [markdown]
# There does not seem to be anything unusual.

# %% [markdown]
# #### deceased_date

# %% [markdown]
# There are not many values in this column.
#
# We just want to make sure that, if there is a date in this column, the `state` column is not null. If `state` is null, then we want to mark it as `deceased`.
#
# If there is an instance where there is a date in the `deceased_date` column but the `state` column has another value than `deceased`, we won't make changes as we cannot be sure which value is accurate.
#
# Once we finish, we will drop the `deceased_date` column.

# %%
df['deceased_date'][df['deceased_date'].isna() == False].shape
# Out:
# (32,)

# %%
df['deceased_date'].dtype
# Out:
# dtype('O')

# %%
df['state'].value_counts()
# Out:
# state
# isolated    1791
# released     307
# deceased      32
# Name: count, dtype: int64

# %%
df[(df['state'] != 'deceased') & (df['deceased_date'].isna() == False)]
# Out:
#      patient_id  global_num     sex  birth_year   age country province  \
# 109  1000000110      6781.0    male      1964.0  55.0   Korea    Seoul
# 187  1000000188      7561.0  female      1994.0  25.0   Korea    Seoul
#
#               city disease        infection_case  infection_order  \
# 109     Gangnam-gu       0  contact with patient         2.285714
# 187  Dongdaemun-gu       0  contact with patient         2.285714
#
#       infected_by  contact_number   symptom_onset_date       confirmed_date  \
# 109  2.600789e+09       24.128954  2020-03-07 00:00:00  2020-03-07 00:00:00
# 187  1.000000e+09       24.128954  2020-03-10 00:00:00  2020-03-10 00:00:00
#
#     released_date deceased_date     state birth_year_dt  n_age
# 109           NaN    2020-03-19  released    1964-01-01   62.0
# 187           NaN    2020-03-19  released    1994-01-01   32.0

# %%
df.loc[(df['state'] != 'deceased') & (df['deceased_date'].isna() == False), 'state'] = 'deceased'

# %%
df['state'].value_counts()
# Out:
# state
# isolated    1791
# released     305
# deceased      34
# Name: count, dtype: int64

# %% [markdown]
# #### released_date

# %% [markdown]
# Check to see if there are any instances where there is a value in the `released_date` col but the `state` does not equal `released`.

# %%
df['released_date'][df['released_date'].isna() == False].shape
# Out:
# (223,)

# %%
df[(df['state'] != 'released') & (df['released_date'].isna() == False)]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state, birth_year_dt, n_age]
# Index: []

# %% [markdown]
# There are no such values. Therefore, we can consider this matter resolved.

# %% [markdown]
# #### birth_year and n_age

# %% [markdown]
# The `n_age` column still has null values, because -- by the original notebook instructions -- the instruction to set null values to the mean came after we created the `n_age` column.

# %%
df[['birth_year', 'birth_year_dt', 'n_age']][df['birth_year_dt'].isna() == True].head(3)
# Out:
#      birth_year birth_year_dt  n_age
# 446      1974.0           NaT    NaN
# 447      1974.0           NaT    NaN
# 448      1974.0           NaT    NaN

# %%
temp_mask_idx = df[df['n_age'].isna() == True].index

# %%
df.loc[temp_mask_idx, 'n_age'] = datetime.now().year - df.loc[temp_mask_idx, 'birth_year']

# %%
df[['birth_year', 'birth_year_dt', 'n_age']][df['birth_year_dt'].isna() == True].head(3)
# Out:
#      birth_year birth_year_dt  n_age
# 446      1974.0           NaT   52.0
# 447      1974.0           NaT   52.0
# 448      1974.0           NaT   52.0

# %%
df = df.drop(columns=['birth_year_dt'])

# %% [markdown]
#  **<font color='teal'> Check for any remaining null values.</font>**

# %%
df.isna().sum()
# Out:
# patient_id               0
# global_num               0
# sex                      0
# birth_year               0
# age                      0
# country                  0
# province                 0
# city                     0
# disease                  0
# infection_case           0
# infection_order          0
# infected_by              0
# contact_number           0
# symptom_onset_date       0
# confirmed_date           0
# released_date         1995
# deceased_date         2186
# state                   88
# n_age                    0
# dtype: int64

# %% [markdown]
# We want the `state` null values to remain, since those are our target.
#
# The missing date values are irrelevant because we're about to drop those.

# %% [markdown]
# Remove date columns from the data.

# %%
df = df.drop(['symptom_onset_date','confirmed_date','released_date','deceased_date'],axis =1)

# %% [markdown]
# Remove redunant year/age info.

# %%
df = df.drop(['birth_year', 'age'], axis=1)

# %% [markdown]
# Review the count of unique values by column.

# %%
print(df.nunique())
# Out:
# patient_id         2218
# global_num         1304
# sex                   2
# country               4
# province             17
# city                139
# disease               2
# infection_case       16
# infection_order       7
# infected_by         207
# contact_number       73
# state                 3
# n_age                96
# dtype: int64

# %% [markdown]
# Review the percent of unique values by column.

# %%
print(df.nunique()/df.shape[0])
# Out:
# patient_id         1.000000
# global_num         0.587917
# sex                0.000902
# country            0.001803
# province           0.007665
# city               0.062669
# disease            0.000902
# infection_case     0.007214
# infection_order    0.003156
# infected_by        0.093327
# contact_number     0.032913
# state              0.001353
# n_age              0.043282
# dtype: float64

# %% [markdown]
# Review the range of values per column.

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# patient_id       2218.0  4.014678e+09  2.192419e+09  1.000000e+09
# global_num       2218.0  4.664817e+03  2.211785e+03  1.000000e+00
# infection_order  2218.0  2.285714e+00  1.706622e-01  1.000000e+00
# infected_by      2218.0  2.600789e+09  7.216328e+08  1.000000e+09
# contact_number   2218.0  2.412895e+01  3.917141e+01  0.000000e+00
# n_age            2218.0  5.121371e+01  1.731583e+01  6.000000e+00
#
#                           25%           50%           75%           max
# patient_id       1.700000e+09  6.001000e+09  6.004000e+09  7.000000e+09
# global_num       4.205250e+03  4.664817e+03  5.900250e+03  8.717000e+03
# infection_order  2.285714e+00  2.285714e+00  2.285714e+00  6.000000e+00
# infected_by      2.600789e+09  2.600789e+09  2.600789e+09  6.113000e+09
# contact_number   2.412895e+01  2.412895e+01  2.412895e+01  1.160000e+03
# n_age            3.800000e+01  5.200000e+01  6.100000e+01  1.100000e+02

# %% [markdown]
# ### Check for duplicated rows

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, state, n_age]
# Index: []

# %% [markdown]
# Print the categorical columns and their associated levels.

# %%
dfo = df.select_dtypes(include=['object'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn = vn.sort_values(by='LevelsCount', ascending=False)
vn
# Out:
#           VarName  LevelsCount
# 3            city          139
# 2        province           17
# 5  infection_case           16
# 1         country            4
# 6           state            3
# 0             sex            2
# 4         disease            2

# %% [markdown]
# **<font color='teal'> Plot the correlation heat map for the features.</font>**

# %%
df_corr = df.drop(columns=vn['VarName']).corr()

# %%
df_corr.columns
# Out:
# Index(['patient_id', 'global_num', 'infection_order', 'infected_by',
#        'contact_number', 'n_age'],
#       dtype='object')

# %%
sns.heatmap(df_corr)
plt.show()

# %% [markdown]
# Everything looks okay.

# %% [markdown]
# **<font color='teal'> Plot the boxplots to check for outliers. </font>**

# %%
df_lim = df.drop(columns=vn['VarName'])

# %%
# Based on Google search response
fig, axes = plt.subplots(ncols=len(df_lim.columns), nrows=1, figsize=(12, 5))

for i, col in enumerate(df_lim.columns):
    sns.boxplot(y=df[col], ax=axes[i])
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### infected_by

# %% [markdown]
# What is this column supposed to mean? I checked on Kaggle and the column is not listed.
#
# Earlier, we saw that `infected_by` is correlated with `patient_id`.

# %%
df[['infected_by', 'patient_id']].head()
# Out:
#     infected_by  patient_id
# 0  2.600789e+09  1000000001
# 1  2.600789e+09  1000000002
# 2  2.002000e+09  1000000003
# 3  2.600789e+09  1000000004
# 4  1.000000e+09  1000000005

# %%
df[['infected_by', 'patient_id']].describe()
# Out:
#         infected_by    patient_id
# count  2.218000e+03  2.218000e+03
# mean   2.600789e+09  4.014678e+09
# std    7.216328e+08  2.192419e+09
# min    1.000000e+09  1.000000e+09
# 25%    2.600789e+09  1.700000e+09
# 50%    2.600789e+09  6.001000e+09
# 75%    2.600789e+09  6.004000e+09
# max    6.113000e+09  7.000000e+09

# %% [markdown]
# These seem to indicate a pattern of infection, going from patient to patient. I wonder if this is valuable for our purposes?
#
# `infected_by` was originally mostly null values. As per the instructions, we inserted the mean for most of the values.
#
# This is a highly suspicious content for this use case of this data, but I will leave it in due to the instructions.

# %% [markdown]
# #### infection_order

# %%
df['infection_order'].unique()
# Out:
# array([1.        , 2.        , 3.        , 4.        , 5.        ,
#        2.28571429, 6.        ])

# %%
df['infection_order'].value_counts()
# Out:
# infection_order
# 2.285714    2176
# 2.000000      19
# 1.000000      11
# 3.000000       6
# 5.000000       3
# 4.000000       2
# 6.000000       1
# Name: count, dtype: int64

# %% [markdown]
# The `infection_order` mean should probably be moved to `2`.

# %%
temp_mask = df['infection_order'][~df['infection_order'].isin([1, 2, 3, 4, 5, 6])].index

# %%
df.loc[temp_mask, 'infection_order'] = 2

# %%
df['infection_order'].unique()
# Out:
# array([1., 2., 3., 4., 5., 6.])

# %%
df['infection_order'].value_counts()
# Out:
# infection_order
# 2.0    2195
# 1.0      11
# 3.0       6
# 5.0       3
# 4.0       2
# 6.0       1
# Name: count, dtype: int64

# %% [markdown]
# That should conclude the outliers.

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
df_X_pre = df.drop(columns=['state'], axis=1)
col_X_pre = pd.DataFrame(vn['VarName'])

# %%
col_X_pre = col_X_pre[col_X_pre['VarName'] != 'state']

# %%
col_X_pre
# Out:
#           VarName
# 3            city
# 2        province
# 5  infection_case
# 1         country
# 0             sex
# 4         disease

# %%
df_X_pre
# Out:
#       patient_id   global_num     sex country          province         city  \
# 0     1000000001     2.000000    male   Korea             Seoul   Gangseo-gu
# 1     1000000002     5.000000    male   Korea             Seoul  Jungnang-gu
# 2     1000000003     6.000000    male   Korea             Seoul    Jongno-gu
# 3     1000000004     7.000000    male   Korea             Seoul      Mapo-gu
# 4     1000000005     9.000000  female   Korea             Seoul  Seongbuk-gu
# ...          ...          ...     ...     ...               ...          ...
# 2213  6100000085  4664.816591    male   Korea  Gyeongsangnam-do  Changwon-si
# 2214  7000000001   139.000000    male   Korea           Jeju-do      Jeju-do
# 2215  7000000002   222.000000  female   Korea           Jeju-do      Jeju-do
# 2216  7000000003  4345.000000  female   Korea           Jeju-do          etc
# 2217  7000000004  5534.000000    male   Korea           Jeju-do      Jeju-do
#
# ...

# %%
X = pd.get_dummies(df_X_pre, columns=col_X_pre['VarName'])

# %%
X
# Out:
#       patient_id   global_num  infection_order   infected_by  contact_number  \
# 0     1000000001     2.000000              1.0  2.600789e+09       75.000000
# 1     1000000002     5.000000              1.0  2.600789e+09       31.000000
# 2     1000000003     6.000000              2.0  2.002000e+09       17.000000
# 3     1000000004     7.000000              1.0  2.600789e+09        9.000000
# 4     1000000005     9.000000              2.0  1.000000e+09        2.000000
# ...          ...          ...              ...           ...             ...
# 2213  6100000085  4664.816591              2.0  2.600789e+09       24.128954
# 2214  7000000001   139.000000              2.0  2.600789e+09       87.000000
# 2215  7000000002   222.000000              2.0  2.600789e+09       84.000000
# 2216  7000000003  4345.000000              2.0  2.600789e+09       21.000000
# 2217  7000000004  5534.000000              2.0  2.600789e+09       74.000000
#
# ...

# %%
y = df['state']

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split

# dont forget to define your X and y

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
class_names=['isolated','released','missing','deceased'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.
